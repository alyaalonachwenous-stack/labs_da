# %%
import urllib.request
import zipfile
import os

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00235/household_power_consumption.zip"
zip_name = "power_data.zip"

if not os.path.exists('household_power_consumption.txt'):
    urllib.request.urlretrieve(url, zip_name)
    
    with zipfile.ZipFile(zip_name, 'r') as zip_ref:
        zip_ref.extractall() 
        
    os.remove(zip_name)
    print("готово")
else:
    print("файл 'household_power_consumption.txt' вже знаходиться у правильній папці")
# Out:
# файл 'household_power_consumption.txt' вже знаходиться у правильній папці

# %% [markdown]
# Здійснити data cleaning

# %%
import pandas as pd
import numpy as np
import timeit

filepath = 'household_power_consumption.txt'

def data_cleaning(filepath):

    df = pd.read_csv(filepath, sep = ';', na_values = ['?'], low_memory = False)

    df['datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format = '%d/%m/%Y %H:%M:%S')
    df.drop(columns = ['Date', 'Time'], inplace = True)

    df.dropna(inplace = True)

    return df

# %%
df = data_cleaning(filepath)
display(df.head())
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                4.216                  0.418   234.84              18.4
# 1                5.360                  0.436   233.63              23.0
# 2                5.374                  0.498   233.29              23.0
# 3                5.388                  0.502   233.74              23.0
# 4                3.666                  0.528   235.68              15.8
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3            datetime
# 0             0.0             1.0            17.0 2006-12-16 17:24:00
# 1             0.0             1.0            16.0 2006-12-16 17:25:00
# 2             0.0             2.0            17.0 2006-12-16 17:26:00
# 3             0.0             1.0            17.0 2006-12-16 17:27:00
# 4             0.0             1.0            17.0 2006-12-16 17:28:00

# %% [markdown]
# Обрати всі записи, у яких загальна активна споживана потужність перевищує 5 кВт.

# %%
def global_active_power_morethan5(df):
    start_time = timeit.default_timer()
    df_1 = df[df['Global_active_power'] > 5]
    
    end_time = timeit.default_timer()
    time = (end_time) - (start_time)
    return df_1, time

# %%
result_1, time_1 = global_active_power_morethan5(df)
print(f"time: {time_1} sec")
display(result_1.head())
# Out:
# time: 0.005672200000844896 sec
#     Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 1                 5.360                  0.436   233.63              23.0
# 2                 5.374                  0.498   233.29              23.0
# 3                 5.388                  0.502   233.74              23.0
# 11                5.412                  0.470   232.78              23.2
# 12                5.224                  0.478   232.99              22.4
#
#     Sub_metering_1  Sub_metering_2  Sub_metering_3            datetime
# 1              0.0             1.0            16.0 2006-12-16 17:25:00
# 2              0.0             2.0            17.0 2006-12-16 17:26:00
# 3              0.0             1.0            17.0 2006-12-16 17:27:00
# 11             0.0             1.0            17.0 2006-12-16 17:35:00
# 12             0.0             1.0            16.0 2006-12-16 17:36:00

# %% [markdown]
# Обрати всі записи, у яких сила струму лежить в межах 19-20 А, для них виявити ті, у яких пральна машина та холодильних споживають більше, ніж бойлер та кондиціонер.

# %%
def intensity1920_washingmaschine_fridge(df):
    start_time = timeit.default_timer()
    df_2 = df[(df['Global_intensity'].between(19, 20))&(df['Sub_metering_2'] > df['Sub_metering_3'])]

    end_time = timeit.default_timer()
    time = end_time - start_time

    return df_2, time

# %%
result_2, time_2 = intensity1920_washingmaschine_fridge(df)
print(f"time: {time_2} sec")
display(result_2.head())
# Out:
# time: 0.01633929996751249 sec
#      Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 45                 4.464                  0.136   234.66              19.0
# 460                4.582                  0.258   238.08              19.6
# 464                4.618                  0.104   239.61              19.6
# 475                4.636                  0.140   237.37              19.4
# 476                4.634                  0.152   237.17              19.4
#
#      Sub_metering_1  Sub_metering_2  Sub_metering_3            datetime
# 45              0.0            37.0            16.0 2006-12-16 18:09:00
# 460             0.0            13.0             0.0 2006-12-17 01:04:00
# 464             0.0            27.0             0.0 2006-12-17 01:08:00
# 475             0.0            36.0             0.0 2006-12-17 01:19:00
# 476             0.0            35.0             0.0 2006-12-17 01:20:00

# %% [markdown]
# Обрати випадковим чином 500000 записів (без повторів елементів вибірки), для них обчислити середні величини усіх 3-х груп споживання електричної енергії

# %%
def random_500k_average(df):
    start_time = timeit.default_timer()
    df_3 = df.sample(n = 500000, replace = False)

    df_stats = df_3[['Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']].mean()
    end_time = timeit.default_timer()
    time = end_time - start_time
    return df_stats, time

# %%
result_3, time_3 = random_500k_average(df)
print(f'time: {time_3} sec')
display(result_3)
# Out:
# time: 0.17458810005337 sec
# Sub_metering_1    1.123396
# Sub_metering_2    1.288936
# Sub_metering_3    6.463668
# dtype: float64

# %% [markdown]
# Обрати ті записи, які після 18-00 споживають понад 6 кВт за хвилину в середньому, серед відібраних визначити ті, у яких основне споживання електроенергії у вказаний проміжок часу припадає на пральну машину, сушарку, холодильник та освітлення (група 2 є найбільшою), а потім обрати кожен третій результат із першої половини та кожен четвертий результат із другої половини.

# %%
def after1800_morethan6kW(df):
    start_time = timeit.default_timer()

    df_fltrd = df[(df['datetime'].dt.hour >= 18)&(df['Global_active_power'] > 6)&(df['Sub_metering_2'] > df['Sub_metering_1'])&(df['Sub_metering_2'] > df['Sub_metering_3'])]

    mid = len(df_fltrd) // 2
    half_1 = df_fltrd.iloc[:mid:3]
    half_2 = df_fltrd.iloc[mid::4]

    fin_res = pd.concat([half_1, half_2])
    end_time = timeit.default_timer()
    time = end_time - start_time
    return fin_res, time

# %%
result_4, time_4 = after1800_morethan6kW(df)
print(f'time : {time_4} sec')
display(result_4.head())
# Out:
# time : 0.05915109999477863 sec
#        Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 41                   6.052                  0.192   232.93              26.2
# 44                   6.308                  0.116   232.25              27.0
# 17494                6.386                  0.374   236.63              27.0
# 17498                8.088                  0.262   235.50              34.4
# 17501                7.230                  0.152   235.22              30.6
#
#        Sub_metering_1  Sub_metering_2  Sub_metering_3            datetime
# 41                0.0            37.0            17.0 2006-12-16 18:05:00
# 44                0.0            36.0            17.0 2006-12-16 18:08:00
# 17494             1.0            36.0            17.0 2006-12-28 20:58:00
# 17498             1.0            72.0            17.0 2006-12-28 21:02:00
# 17501             1.0            73.0            17.0 2006-12-28 21:05:00

# %% [markdown]
# імпорт бібліотек

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# створюю копії фрейму

# %%
df_std = result_2.copy() 
df_norm = result_2.copy()

# %% [markdown]
# Пронормувати та стандартизувати вибраний датасет

# %% [markdown]
# 1.стандартизація

# %%
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage', 
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3'
]

std_scaler = StandardScaler() #використовую StandardScaler для стандартизації
df_std[numeric_cols] = std_scaler.fit_transform(df_std[numeric_cols]) #стандартизований датафрейм

display(df_std[numeric_cols].head(3))
# Out:
#      Global_active_power  Global_reactive_power   Voltage  Global_intensity  \
# 45             -1.120974              -0.483627 -0.690133         -1.416574
# 460            -0.048414               0.217533  0.476645          0.358152
# 464             0.278807              -0.667537  0.998625          0.358152
#
#      Sub_metering_1  Sub_metering_2  Sub_metering_3
# 45        -0.435351        0.079434        0.544519
# 460       -0.435351       -1.443879       -1.343472
# 464       -0.435351       -0.555280       -1.343472

# %% [markdown]
# 2.нормування

# %%
minmax_scaler = MinMaxScaler() #використовую MinMaxScaler для нормування
df_norm[numeric_cols] = minmax_scaler.fit_transform(df_norm[numeric_cols])

display(df_norm[numeric_cols].head(3)) #пронормований датафрейм
#для наочності дві дії - стандартизацію та нормування, роблю на окремих копіях фрейму
# Out:
#      Global_active_power  Global_reactive_power   Voltage  Global_intensity  \
# 45              0.539648               0.128302  0.357955               0.0
# 460             0.669604               0.243396  0.519886               0.6
# 464             0.709251               0.098113  0.592330               0.6
#
#      Sub_metering_1  Sub_metering_2  Sub_metering_3
# 45              0.0        0.480000        0.533333
# 460             0.0        0.160000        0.000000
# 464             0.0        0.346667        0.000000

# %% [markdown]
# Підрахувати коефіцієнт Пірсона та Спірмена для двох integer/real атрибутів

# %%
col_1 = 'Global_active_power'
col_2 = 'Global_intensity'

pearson_corr = result_2[col_1].corr(result_2[col_2], method='pearson')

spearman_corr = result_2[col_1].corr(result_2[col_2], method='spearman')

print(f"кореляція Пірсона: {pearson_corr:.4f}")
print(f"кореляція Спірмена: {spearman_corr:.4f}")
# Out:
# кореляція Пірсона: 0.6995
# кореляція Спірмена: 0.7285

# %% [markdown]
# Провести One Hot Encoding категоріального атрибута

# %% [markdown]
# відділяю день тижня з колонки datetime і проводжу для цього атрибута One Hot Encoding

# %%
result_2['day_of_week'] = result_2['datetime'].dt.day_name() #тут відділяю день тижня з об'єднаної колонки datetime

result_2_ohe = pd.get_dummies(result_2, columns=['day_of_week']) #тут One Hot Encoding
display(result_2_ohe.head())
# Out:
#      Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 45                 4.464                  0.136   234.66              19.0
# 460                4.582                  0.258   238.08              19.6
# 464                4.618                  0.104   239.61              19.6
# 475                4.636                  0.140   237.37              19.4
# 476                4.634                  0.152   237.17              19.4
#
#      Sub_metering_1  Sub_metering_2  Sub_metering_3            datetime  \
# 45              0.0            37.0            16.0 2006-12-16 18:09:00
# 460             0.0            13.0             0.0 2006-12-17 01:04:00
# 464             0.0            27.0             0.0 2006-12-17 01:08:00
# 475             0.0            36.0             0.0 2006-12-17 01:19:00
# 476             0.0            35.0             0.0 2006-12-17 01:20:00
#
#      day_of_week_Friday  day_of_week_Monday  day_of_week_Saturday  \
# 45                False               False                  True
# 460               False               False                 False
# 464               False               False                 False
# 475               False               False                 False
# 476               False               False                 False
#
#      day_of_week_Sunday  day_of_week_Thursday  day_of_week_Tuesday  \
# 45                False                 False                False
# 460                True                 False                False
# 464                True                 False                False
# 475                True                 False                False
# 476                True                 False                False
#
#      day_of_week_Wednesday
# 45                   False
# 460                  False
# 464                  False
# 475                  False
# 476                  False
